# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('../data/amsterdamcars.xlsx')

data = data.replace(np.nan, '', regex=True)

# %%
data
# Out:
#    4.1.1   Motorvoertuigen in Amsterdam, 1 januari 2000-2019 1) Unnamed: 1  \
# 0
# 1                                                                     2000
# 2
# 3                             Total all vehicle types               266653
# 4                                      Passenger cars               227059
# 5                           Total commercial vehicles                28774
# 6                     Total commercial motor vehicles                28774
# 7                                       Delivery vans                24882
# 8                                              Trucks                 1891
# 9                               Tractors for trailers                  624
# 10                                   Special vehicles                  979
# 11                                              Buses                  398
# 12                                        Motorcycles                10820
# ...

# %%
data = data.drop([0,2,14,15,16,17,18], axis = 0)

data
# Out:
#    4.1.1   Motorvoertuigen in Amsterdam, 1 januari 2000-2019 1) Unnamed: 1  \
# 1                                                                     2000
# 3                             Total all vehicle types               266653
# 4                                      Passenger cars               227059
# 5                           Total commercial vehicles                28774
# 6                     Total commercial motor vehicles                28774
# 7                                       Delivery vans                24882
# 8                                              Trucks                 1891
# 9                               Tractors for trailers                  624
# 10                                   Special vehicles                  979
# 11                                              Buses                  398
# 12                                        Motorcycles                10820
# ...

# %%
data = data.drop(["Unnamed: 7", "Unnamed: 8"], axis = 1)

# %%
data = data.rename(columns={'Unnamed: 1':'2000', 'Unnamed: 2' : '2015', 'Unnamed: 3' : '2016',
                           'Unnamed: 4' : '2017', 'Unnamed: 5' : '2018', 'Unnamed: 6' : '2019'})

# %%
data = data.rename(columns={'4.1.1   Motorvoertuigen in Amsterdam, 1 januari 2000-2019 1)': 'Type of Cars'})

# %%
data = data.drop([1], axis = 0)
data
# Out:
#                             Type of Cars    2000    2015    2016    2017  \
# 3                Total all vehicle types  266653  336859  342051  346530
# 4                         Passenger cars  227059  228691  231183  233715
# 5              Total commercial vehicles   28774   33906   33856   34379
# 6        Total commercial motor vehicles   28774   23482   23331   23716
# 7                          Delivery vans   24882   20009   19910   20332
# 8                                 Trucks    1891    1096    1050    1108
# 9                  Tractors for trailers     624     684     677     700
# 10                      Special vehicles     979    1413    1411    1292
# 11                                 Buses     398     280     283     284
# 12                           Motorcycles   10820   18009   18320   18751
# 13  All vehicles with moped registration       .   56253   58692   59685
#
#       2018    2019
# 3   345937  342803
# 4   234256  235026
# 5    34551   34482
# ...
